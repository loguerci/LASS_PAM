# %%
import audio as aud
import librosa as lr
from IPython.display import display, Audio
import os
import numpy as np

audio_dir = "/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems"
audios = [aud.load_audio_segment(os.path.join(audio_dir, f)) for f in os.listdir(audio_dir) if f.endswith(".wav")]
res = aud.scatter_audio_segments(audios, mix_duration_s=30, mix_division=5, instance_probability=.5, max_seg_duration_s=5.0)

display(Audio(res, rate=16000))
# Out:
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (384000, 480000)
# 2701541 80000 480000 25676 79999
# 2701541 80000 480000 151580 79999
# 2701541 80000 480000 264253 79999
# 2701541 80000 480000 443443 36556
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (384000, 480000)
# 3710838 80000 480000 55895 79999
# 3710838 80000 480000 233516 79999
# 3710838 80000 480000 467724 12275
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (384000, 480000)
# 1686342 80000 480000 1343 79999
# 1686342 80000 480000 284992 79999
# 1686342 80000 480000 455813 24186
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (384000, 480000)
# 552270 80000 480000 17422 79999
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (384000, 480000)
# 2135659 80000 480000 34737 79999
# 2135659 80000 480000 333862 79999
# 2135659 80000 480000 429525 50474
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (384000, 480000)
# 1940127 80000 480000 6887 79999
# 1940127 80000 480000 318651 79999
# 1940127 80000 480000 468612 11387
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (384000, 480000)
# 3214816 80000 480000 8239 79999
# 3214816 80000 480000 151369 79999
# 3214816 80000 480000 274038 79999
# 3214816 80000 480000 376054 79999
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (384000, 480000)
# 3730248 80000 480000 79518 79999
# 3730248 80000 480000 160891 79999
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (384000, 480000)
# 1199367 80000 480000 61439 79999
# 1199367 80000 480000 208472 79999
# 1199367 80000 480000 309242 79999
# 1199367 80000 480000 413478 66521
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (0, 96000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (96000, 192000)
# audio.scatter_audio_segments : instance success True for segment length 80000 in mix segment (192000, 288000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (288000, 384000)
# audio.scatter_audio_segments : instance success False for segment length 80000 in mix segment (384000, 480000)
# 3685631 80000 480000 2489 79999
# 3685631 80000 480000 164654 79999
# 3685631 80000 480000 248089 79999
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

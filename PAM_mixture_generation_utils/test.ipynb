# %%
import audio as aud
import parsing
import librosa as lr
from IPython.display import display, Audio
import os
import numpy as np
from pathlib import Path
from importlib import reload
reload(aud)


MIX_LENGTH = 10
SAMPLE_RATE = 16000


audio_dir = "/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems"
audios = [aud.load_audio_segment(os.path.join(audio_dir, f)) for f in os.listdir(audio_dir) if f.endswith(".wav")]
res = aud.scatter_audio_segments(audios, mix_duration_s=30, mix_division=5, instance_probability=.5, max_seg_duration_s=5.0)

display(Audio(res, rate=16000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
res = parsing.track_metadata(Path("/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002"))
for s, v in res['stems'].items():
    print(s, v['midi_program_name'])

res = parsing.track_stems_and_instr(res)
print(res)
filt = ["string", "violin", "piano", "choir"]
reject = ["electric"]
print(parsing.filter_stems_by_keywords(res, filt, reject))
# Out:
# S00 Synth Strings 1
# S01 Electric Bass (pick)
# S02 Lead 2 (sawtooth)
# S03 Pad 1 (new age)
# S04 Choir Aahs
# S05 Music Box
# S06 Clavinet
# S07 Brass Section
# S08 Electric Guitar (muted)
# S09 Drums
# S10 Woodblock
# S11 Orchestra Hit
# {'S00': 'Synth Strings 1', 'S01': 'Electric Bass (pick)', 'S02': 'Lead 2 (sawtooth)', 'S03': 'Pad 1 (new age)', 'S04': 'Choir Aahs', 'S05': 'Music Box', 'S06': 'Clavinet', 'S07': 'Brass Section', 'S08': 'Electric Guitar (muted)', 'S09': 'Drums', 'S10': 'Woodblock', 'S11': 'Orchestra Hit'}
# {'string': {'S00': 'Synth Strings 1'}, 'violin': {}, 'piano': {}, 'choir': {'S04': 'Choir Aahs'}}

# %%
filt = ["string", "violin", "piano", "choir"]
rej = ["electric"]


instr_sets = dict()

dataset_dir = "/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/"

def instrument_sets(dataset_dir : Path) -> dict[str, list[Path]]:
    instr_sets = dict()
    for f in os.listdir(dataset_dir):
        if not os.path.isdir(os.path.join(dataset_dir, f)):
            print(f"{f} is not a directory, skipping")
            continue
        meta = parsing.track_metadata(os.path.join(dataset_dir,f))
        instrs = parsing.track_stems_and_instr(meta)
        for s, i in instrs.items():
            if i not in instr_sets :
                instr_sets[i] = list()
            instr_sets[i].append(Path(os.path.join(dataset_dir, f + '/stems/' + s + '.wav')))
    return instr_sets

def filter_dataset_by_keywords(dataset_dir, filt, rej):
    for f in os.listdir(dataset_dir):
        if not os.path.isdir(os.path.join(dataset_dir, f)):
            print(f"{f} is not a directory, skipping")
            continue
        meta = parsing.track_metadata(Path(dataset_dir + f))
        for inst, stem_midi in parsing.filter_stems_by_keywords(parsing.track_stems_and_instr(meta), filt, rej).items():
            if inst not in instr_sets:
                instr_sets[inst] = dict()
            for s, i in stem_midi.items():
                instr_sets[inst][f + '/' + 'stems' + '/' + s + '.wav'] = i
    return instr_sets

def filter_instr_by_keywords(instr_sets:dict[str, list[Path]], filt, rej) -> dict[str, list[Path]]:
    res = dict()
    for f in filt:
        if f not in res:
            res[f] = list()
        print(instr_sets)
        for inst, stems in instr_sets.items():
            if f.upper() in inst.upper() and not any(r.upper() in inst.upper() for r in rej):
                res[f] += stems
    return res


print(filter_instr_by_keywords(instrument_sets(dataset_dir), filt, rej))
# Out:
# {'Synth Strings 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S11.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S05.wav')], 'Electric Piano 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S01.wav')], 'Drums': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00011/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S17.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00010/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00003/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00009/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00008/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S08.wav')], 'Vibraphone': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S14.wav')], 'Flute': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S07.wav'), PosixPath('/home/eilen/C ...
# {'Synth Strings 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S11.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S05.wav')], 'Electric Piano 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S01.wav')], 'Drums': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00011/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S17.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00010/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00003/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00009/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00008/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S08.wav')], 'Vibraphone': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S14.wav')], 'Flute': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S07.wav'), PosixPath('/home/eilen/C ...
# {'Synth Strings 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S11.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S05.wav')], 'Electric Piano 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S01.wav')], 'Drums': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00011/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S17.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00010/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00003/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00009/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00008/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S08.wav')], 'Vibraphone': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S14.wav')], 'Flute': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S07.wav'), PosixPath('/home/eilen/C ...
# {'Synth Strings 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S11.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S05.wav')], 'Electric Piano 1': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S01.wav')], 'Drums': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00011/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S17.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00010/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00003/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00009/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00007/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00008/stems/S01.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S08.wav')], 'Vibraphone': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S14.wav')], 'Flute': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00013/stems/S07.wav'), PosixPath('/home/eilen/C ...
# {'string': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S11.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00009/stems/S10.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00008/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S04.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00006/stems/S05.wav')], 'violin': [], 'piano': [PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00019/stems/S12.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00016/stems/S10.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S09.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S06.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00020/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S11.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00008/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00005/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00004/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00017/stems/S08.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00012/stems/S03.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00010/stems/S05.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00014/stems/S10.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00011/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00018/stems/S07.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems/S02.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00015/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00003/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00009/stems/S00.wav'), PosixPath('/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/T ...

# %%
import random
import json


def chose_rand_stems(instrs_and_stems : dict[str, list[Path]], instruments : list[str], n=1) -> list[tuple[str, str, Path]]:
    """ returns a list of n tuples of the form (instrument type (keyword), instrument, stem_path)
        for each keyword in `instruments`,
        where instrument is a random instrument matching the keyword
        stem_path is a random stem path for that instrument. """
    matches = {i: [k for k in instrs_and_stems if i.upper() in k.upper()] for i in instruments}
    return [(i, k:=random.choice(matches[i]), random.choice(instrs_and_stems[k])) for i in instruments for _ in range(n)]



def build_datapoint(instrs_and_stems : dict[str, list[Path]], filtered_instr_and_stems : dict[str, list[Path]], prompt_target_recording:tuple[str, str, Path], mix_duration_s=30, mix_division=5, instance_probability=.5, max_seg_duration_s=5.0):
    res = dict()
    metadata = dict()
    background_instruments = set()
    while len(background_instruments) < 4:
        attempt = None
        while attempt is None:
            b = random.choice(list(instrs_and_stems.keys()))
            if prompt_target_recording[0].upper() not in b.upper():
                attempt = aud.load_audio_segment(random.choice(instrs_and_stems[b]))
                if attempt is None:
                    print(f"Failed to load background instrument {b}, retrying...")
        background_instruments.add(b)
    background_keyword_instrument_stems = chose_rand_stems(instrs_and_stems, list(background_instruments), n=1)

    _prompt_instr = [i for i in filtered_instr_and_stems.keys() if prompt_target_recording[0].upper() in i.upper()]
    reference = None
    for i in range(10):
        reference = aud.normalize_energy(aud.get_active_audio(aud.load_audio_segment(x := random.choice(filtered_instr_and_stems[random.choice(_prompt_instr)]))))
        print(x)
        if reference is not None:
            break
    if reference is None:
        raise Exception(f"Could not load reference audio for prompt {prompt_target_recording[0]} after 10 attempts")
    reference = reference[:min(MIX_LENGTH * SAMPLE_RATE, len(reference))]
    
    target_raw = None
    for i in range(10):
        target_raw = aud.normalize_energy(aud.load_audio_segment(prompt_target_recording[2]))
        if target_raw is not None:
            break
    if target_raw is None:
        raise Exception(f"Could not load target audio for prompt {prompt_target_recording[0]} after 10 attempts")

    mixture = aud.scatter_audio_segments([aud.load_audio_segment(b[2]) for b in background_keyword_instrument_stems], mix_duration_s=mix_duration_s, mix_division=mix_division, instance_probability=instance_probability, max_seg_duration_s=max_seg_duration_s)

    res['reference'] = reference
    res['target'] = aud.scatter_audio_segments([target_raw], mix_duration_s=mix_duration_s, mix_division=mix_division, instance_probability=instance_probability, max_seg_duration_s=max_seg_duration_s)
    mixture += res['target']
    mixture = aud.normalize_energy(mixture, alpha=.9)
    res['mixture'] = mixture

    metadata['prompt'] = prompt_target_recording[0]
    metadata['target_instrument'] = prompt_target_recording[1]
    metadata['background_instruments'] = [b[1] for b in background_keyword_instrument_stems]

    meta_json = json.dumps(metadata)
    return res, meta_json, background_instruments

def save_datapoint(datapoint : dict[str, np.ndarray], metadata_json : str, save_dir : str):
    os.makedirs(save_dir, exist_ok=True)
    aud.save_audio(os.path.join(save_dir, 'reference.wav'), datapoint['reference'])
    aud.save_audio(os.path.join(save_dir, 'target.wav'), datapoint['target'])
    aud.save_audio(os.path.join(save_dir, 'mixture.wav'), datapoint['mixture'])
    with open(os.path.join(save_dir, 'metadata.json'), 'w') as f:
        f.write(metadata_json)

# %%
dataset_path = Path("/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test")
savepath = Path("/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test_new")
print("loading...")
instrs_and_stems = instrument_sets(dataset_path)
print("instrs_and_stems", instrs_and_stems)
filt = ["violin", "piano", "sax"]
rej = ["electric", "synth"]

filtered = filter_instr_by_keywords(instrs_and_stems, filt, rej)
print("filtered", filtered)

for i in range(100):
    attempt = None
    while attempt is None:
         prompt_target = random.choice(chose_rand_stems(filtered, filt, n=1))
         attempt = aud.load_audio_segment(prompt_target[2])
         if attempt is None:
             print(f"Failed to load prompt target {prompt_target[2]}, retrying...") 
    #background_instruments = set()
    #while len(background_instruments) < 4:
    #    b = random.choice(list(instrs_and_stems.keys()))
    #    if prompt_target[0].upper() not in b.upper():
    #        background_instruments.add(b)
    #background = chose_rand_stems(instrs_and_stems, list(background_instruments), n=1)
    datapoint, metadata_json, background = build_datapoint(instrs_and_stems, filtered, prompt_target, mix_duration_s=10, mix_division=5, instance_probability=.8, max_seg_duration_s=3.0)
    print(i, prompt_target, background, metadata_json)
    save_datapoint(datapoint, metadata_json, os.path.join(savepath, f"example_{i}"))
# Out:
# loading...
# .DS_Store is not a directory, skipping
# ._.DS_Store is not a directory, skipping
# instrs_and_stems {'Electric Bass (finger)': [PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01881/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01887/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01888/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01895/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01896/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01899/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01901/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01902/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01911/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01913/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01974/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01975/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01985/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01986/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S06.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01994/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01995/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01997/stems/S07.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02001/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02002/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02044/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02047/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02049/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02064/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02067/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02069/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02079/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research ...
# {'Electric Bass (finger)': [PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01881/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01887/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01888/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01895/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01896/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01899/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01901/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01902/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01911/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01913/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01974/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01975/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01985/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01986/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S06.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01994/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01995/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01997/stems/S07.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02001/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02002/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02044/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02047/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02049/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02064/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02067/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02069/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02079/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/sl ...
# {'Electric Bass (finger)': [PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01881/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01887/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01888/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01895/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01896/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01899/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01901/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01902/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01911/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01913/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01974/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01975/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01985/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01986/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S06.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01994/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01995/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01997/stems/S07.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02001/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02002/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02044/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02047/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02049/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02064/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02067/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02069/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02079/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/sl ...
# {'Electric Bass (finger)': [PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01881/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01887/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01888/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01895/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01896/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01899/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01901/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01902/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01911/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01913/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01974/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01975/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01985/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01986/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S06.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01994/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01995/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01997/stems/S07.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02001/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02002/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02044/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02047/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02049/stems/S01.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02064/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02067/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02069/stems/S11.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02079/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/sl ...
# filtered {'violin': [PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01897/stems/S13.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01945/stems/S07.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02017/stems/S08.wav')], 'piano': [PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01883/stems/S08.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01884/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01887/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01891/stems/S04.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01897/stems/S08.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S06.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S08.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01908/stems/S02.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01975/stems/S08.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01978/stems/S10.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S08.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01989/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01993/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02002/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02044/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02045/stems/S03.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02048/stems/S00.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02050/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S09.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S10.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02053/stems/S10.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02054/stems/S10.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02061/stems/S08.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02063/stems/S05.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02063/stems/S14.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02064/stems/S16.wav'), PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Dataset ...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02019/stems/S02.wav
# 0 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01902/stems/S05.wav')) {'Rock Organ', 'Alto Sax', 'Lead 4 (chiff)', 'Voice Oohs'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Rock Organ", "Alto Sax", "Lead 4 (chiff)", "Voice Oohs"]}
# /home/eilen/Code/Python/LASS_PAM/PAM_mixture_generation_utils/audio.py:38: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, _ = librosa.load(path, sr=sr)
# /home/eilen/Code/Python/LASS_PAM/.pixi/envs/default/lib/python3.14/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav'
# Failed to load background instrument English Horn, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S05.wav
# 1 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav')) {'Lead 6 (voice)', 'Electric Bass (pick)', 'Drums', 'Clavinet'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Lead 6 (voice)", "Electric Bass (pick)", "Drums", "Clavinet"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav'
# Failed to load background instrument English Horn, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02050/stems/S03.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02050/stems/S03.wav'
# Failed to load background instrument FX 4 (atmosphere), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02016/stems/S05.wav
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01927/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01927/stems/S10.wav'
# audio.scatter_audio_segments : one of the segments is None, skipping this segment
# 2 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01881/stems/S02.wav')) {'Electric Bass (finger)', 'Voice Oohs', 'Tremolo Strings', 'Oboe'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Electric Bass (finger)", "Voice Oohs", "Tremolo Strings", "Oboe"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01889/stems/S13.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01889/stems/S13.wav'
# Failed to load background instrument Timpani, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02052/stems/S09.wav
# 3 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02008/stems/S06.wav')) {'Electric Bass (finger)', 'Piccolo', 'Tuba', 'Electric Bass (pick)'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Electric Bass (finger)", "Piccolo", "Tuba", "Electric Bass (pick)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S12.wav'
# Failed to load background instrument Bag pipe, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav'
# Failed to load background instrument Agogo, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S12.wav'
# Failed to load background instrument Gunshot, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S05.wav
# 4 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav')) {'Lead 6 (voice)', 'Slap Bass 2', 'Electric Guitar (muted)', 'Celesta'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Lead 6 (voice)", "Slap Bass 2", "Electric Guitar (muted)", "Celesta"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01897/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01897/stems/S09.wav'
# Failed to load background instrument Taiko Drum, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav'
# Failed to load background instrument English Horn, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav'
# Failed to load background instrument Agogo, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S06.wav'
# Failed to load background instrument Synth Brass 2, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02005/stems/S05.wav
# 5 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01908/stems/S03.wav')) {'Acoustic Bass', 'Orchestral Harp', 'Synth Strings 1', 'Dulcimer'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Acoustic Bass", "Orchestral Harp", "Synth Strings 1", "Dulcimer"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01947/stems/S00.wav
# 6 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01940/stems/S01.wav')) {'Pad 7 (halo)', 'Pad 2 (warm)', 'Cello', 'Clarinet'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Pad 7 (halo)", "Pad 2 (warm)", "Cello", "Clarinet"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav'
# Failed to load background instrument FX 6 (goblins), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01911/stems/S07.wav
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S09.wav'
# audio.scatter_audio_segments : one of the segments is None, skipping this segment
# 7 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S09.wav')) {'Lead 2 (sawtooth)', 'Drums', 'Choir Aahs', 'Electric Piano 2'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Lead 2 (sawtooth)", "Steel Drums", "Choir Aahs", "Electric Piano 2"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01902/stems/S02.wav
# 8 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01916/stems/S03.wav')) {'French Horn', 'Lead 4 (chiff)', 'Ocarina', 'Electric Piano 2'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["French Horn", "Lead 4 (chiff)", "Ocarina", "Electric Piano 2"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S09.wav'
# Failed to load background instrument Synth Drum, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav
# 9 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02017/stems/S08.wav')) {'Trombone', 'Pad 3 (polysynth)', 'Choir Aahs', 'Acoustic Grand Piano'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Trombone", "Pad 3 (polysynth)", "Choir Aahs", "Acoustic Grand Piano"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S07.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01905/stems/S07.wav'
# Failed to load background instrument FX 8 (sci-fi), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S02.wav
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02056/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02056/stems/S09.wav'
# audio.scatter_audio_segments : one of the segments is None, skipping this segment
# 10 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01896/stems/S00.wav')) {'Pad 2 (warm)', 'Glockenspiel', 'Flute', 'Electric Bass (pick)'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Pad 2 (warm)", "Glockenspiel", "Flute", "Electric Bass (pick)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01889/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01889/stems/S11.wav'
# Failed to load background instrument Reverse Cymbal, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S08.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S08.wav'
# Failed to load background instrument Applause, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02030/stems/S07.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02030/stems/S07.wav'
# Failed to load background instrument FX 3 (crystal), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01895/stems/S03.wav
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S14.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S14.wav'
# audio.scatter_audio_segments : one of the segments is None, skipping this segment
# 11 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02053/stems/S14.wav')) {'Pad 6 (metallic)', 'Shakuhachi', 'Pad 4 (choir)', 'Electric Bass (pick)'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Pad 6 (metallic)", "Shakuhachi", "Pad 4 (choir)", "Electric Bass (pick)"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S05.wav
# 12 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav')) {'Lead 6 (voice)', 'Lead 5 (charang)', 'Synth Strings 1', 'Electric Bass (pick)'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Lead 6 (voice)", "Lead 5 (charang)", "Synth Strings 1", "Electric Bass (pick)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S03.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S03.wav'
# Failed to load background instrument Telephone Ring, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav'
# Failed to load background instrument Agogo, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav
# 13 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02017/stems/S08.wav')) {'Voice Oohs', 'Pan Flute', 'Whistle', 'Percussive Organ'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Voice Oohs", "Pan Flute", "Whistle", "Percussive Organ"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S13.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S13.wav'
# Failed to load background instrument Bird Tweet, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav
# 14 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S05.wav')) {'Pizzicato Strings', 'Piccolo', 'Pad 1 (new age)', 'Slap Bass 1'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Pizzicato Strings", "Piccolo", "Pad 1 (new age)", "Slap Bass 1"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S05.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S05.wav'
# Failed to load background instrument Guitar Fret Noise, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav
# 15 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav')) {'Viola', 'Muted Trumpet', 'String Ensemble 2', 'Acoustic Guitar (nylon)'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Viola", "Muted Trumpet", "String Ensemble 2", "Acoustic Guitar (nylon)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S06.wav'
# Failed to load background instrument Synth Brass 2, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02007/stems/S00.wav
# 16 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02069/stems/S04.wav')) {'Pan Flute', 'Fretless Bass', 'Lead 2 (sawtooth)', 'Marimba'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Pan Flute", "Fretless Bass", "Lead 2 (sawtooth)", "Marimba"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02026/stems/S07.wav
# 17 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02038/stems/S11.wav')) {'Lead 5 (charang)', 'Electric Bass (finger)', 'Acoustic Guitar (nylon)', 'Electric Bass (pick)'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Lead 5 (charang)", "Electric Bass (finger)", "Acoustic Guitar (nylon)", "Electric Bass (pick)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02056/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02056/stems/S09.wav'
# Failed to load background instrument Glockenspiel, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01945/stems/S07.wav
# 18 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01945/stems/S07.wav')) {'Tuba', 'Electric Guitar (muted)', 'Cello', 'Tenor Sax'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Tuba", "Electric Guitar (muted)", "Cello", "Tenor Sax"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav'
# Failed to load background instrument FX 6 (goblins), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01943/stems/S06.wav
# 19 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02053/stems/S13.wav')) {'Acoustic Bass', 'Slap Bass 2', 'Synth Strings 1', 'Tuba'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Acoustic Bass", "Slap Bass 2", "Synth Strings 1", "Tuba"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S11.wav'
# Failed to load background instrument FX 5 (brightness), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01945/stems/S07.wav
# 20 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav')) {'Vibraphone', 'Muted Trumpet', 'Electric Guitar (muted)', 'Soprano Sax'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Vibraphone", "Muted Trumpet", "Electric Guitar (muted)", "Soprano Sax"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S09.wav'
# Failed to load background instrument Steel Drums, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S16.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S16.wav'
# Failed to load background instrument Sitar, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01893/stems/S09.wav
# 21 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02064/stems/S17.wav')) {'Pizzicato Strings', 'Percussive Organ', 'Cello', 'Pad 4 (choir)'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Pizzicato Strings", "Percussive Organ", "Cello", "Pad 4 (choir)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S11.wav'
# Failed to load background instrument FX 5 (brightness), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S10.wav'
# Failed to load background instrument FX 8 (sci-fi), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav
# 22 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S05.wav')) {'Trombone', 'Choir Aahs', 'Lead 1 (square)', 'Accordion'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Trombone", "Choir Aahs", "Lead 1 (square)", "Accordion"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02052/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02052/stems/S10.wav'
# Failed to load prompt target /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02052/stems/S10.wav, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S13.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S13.wav'
# Failed to load background instrument Bird Tweet, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01943/stems/S07.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01943/stems/S07.wav'
# Failed to load background instrument Synth Brass 1, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02001/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02001/stems/S06.wav'
# Failed to load background instrument Flute, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01995/stems/S01.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01995/stems/S01.wav'
# Failed to load background instrument FX 7 (echoes), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav'
# Failed to load background instrument FX 6 (goblins), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01887/stems/S03.wav
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02056/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02056/stems/S09.wav'
# audio.scatter_audio_segments : one of the segments is None, skipping this segment
# 23 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02088/stems/S13.wav')) {'Pad 7 (halo)', 'String Ensemble 1', 'Distortion Guitar', 'Glockenspiel'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Pad 7 (halo)", "String Ensemble 1", "Distortion Guitar", "Glockenspiel"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav'
# Failed to load background instrument English Horn, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S17.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S17.wav'
# Failed to load background instrument Timpani, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02045/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02045/stems/S11.wav'
# Failed to load background instrument Woodblock, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S13.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01876/stems/S13.wav'
# Failed to load background instrument Bird Tweet, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02082/stems/S04.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02082/stems/S04.wav'
# Failed to load background instrument Synth Brass 1, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S02.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S02.wav'
# Failed to load background instrument Fiddle, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01945/stems/S07.wav
# 24 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav')) {'Pad 8 (sweep)', 'Synth Voice', 'Distortion Guitar', 'Tenor Sax'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Pad 8 (sweep)", "Synth Voice", "Distortion Guitar", "Tenor Sax"]}
# ...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S09.wav'
# Failed to load background instrument Synth Drum, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav'
# Failed to load background instrument FX 6 (goblins), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S06.wav'
# Failed to load background instrument Synth Brass 2, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S12.wav'
# Failed to load background instrument Bag pipe, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02016/stems/S06.wav
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01927/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01927/stems/S10.wav'
# audio.scatter_audio_segments : one of the segments is None, skipping this segment
# 87 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01968/stems/S00.wav')) {'Oboe', 'Viola', 'String Ensemble 2', 'Clarinet'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Oboe", "Viola", "String Ensemble 2", "Clarinet"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02003/stems/S12.wav'
# Failed to load background instrument Timpani, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav'
# Failed to load background instrument Agogo, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01980/stems/S07.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01980/stems/S07.wav'
# Failed to load background instrument Guitar Fret Noise, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01975/stems/S04.wav
# 88 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01884/stems/S02.wav')) {'Lead 5 (charang)', 'Slap Bass 2', 'Lead 4 (chiff)', 'String Ensemble 1'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Lead 5 (charang)", "Slap Bass 2", "Lead 4 (chiff)", "String Ensemble 1"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02049/stems/S05.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02049/stems/S05.wav'
# Failed to load background instrument Synth Bass 2, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01982/stems/S04.wav
# 89 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01937/stems/S01.wav')) {'Harmonica', 'Distortion Guitar', 'Clarinet', 'Electric Bass (pick)'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Harmonica", "Distortion Guitar", "Clarinet", "Electric Bass (pick)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S04.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S04.wav'
# Failed to load background instrument FX 8 (sci-fi), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S06.wav'
# Failed to load background instrument Banjo, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01934/stems/S13.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01934/stems/S13.wav'
# Failed to load background instrument Reverse Cymbal, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S03.wav
# 90 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S03.wav')) {'Xylophone', 'String Ensemble 2', 'Electric Piano 1', 'Cello'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Xylophone", "String Ensemble 2", "Electric Piano 1", "Cello"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02045/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02045/stems/S11.wav'
# Failed to load background instrument Woodblock, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01889/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01889/stems/S11.wav'
# Failed to load background instrument Reverse Cymbal, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01934/stems/S13.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01934/stems/S13.wav'
# Failed to load background instrument Reverse Cymbal, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02010/stems/S09.wav'
# Failed to load background instrument Agogo, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01996/stems/S03.wav
# 91 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02008/stems/S06.wav')) {'Recorder', 'Pan Flute', 'Electric Grand Piano', 'Church Organ'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Recorder", "Pan Flute", "Electric Grand Piano", "Church Organ"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S03.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S03.wav'
# Failed to load background instrument Telephone Ring, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02053/stems/S05.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02053/stems/S05.wav'
# Failed to load background instrument Synth Bass 1, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01917/stems/S04.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01917/stems/S04.wav'
# Failed to load background instrument FX 4 (atmosphere), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01965/stems/S10.wav'
# Failed to load background instrument English Horn, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01901/stems/S02.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01901/stems/S02.wav'
# Failed to load background instrument Seashore, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01877/stems/S03.wav
# 92 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02053/stems/S14.wav')) {'Acoustic Guitar (nylon)', 'Synth Voice', 'Lead 1 (square)', 'Flute'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Acoustic Guitar (nylon)", "Synth Voice", "Lead 1 (square)", "Pan Flute"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01993/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01993/stems/S06.wav'
# Failed to load background instrument Kalimba, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01982/stems/S05.wav
# 93 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01898/stems/S07.wav')) {'Overdriven Guitar', 'Lead 3 (calliope)', 'Tuba', 'Electric Guitar (clean)'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Overdriven Guitar", "Lead 3 (calliope)", "Tuba", "Electric Guitar (clean)"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S03.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01987/stems/S03.wav'
# Failed to load background instrument Fiddle, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02095/stems/S04.wav
# 94 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02051/stems/S10.wav')) {'Vibraphone', 'Pad 1 (new age)', 'Choir Aahs', 'Cello'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Vibraphone", "Pad 1 (new age)", "Choir Aahs", "Cello"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S04.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S04.wav'
# Failed to load background instrument FX 8 (sci-fi), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01930/stems/S12.wav'
# Failed to load background instrument FX 6 (goblins), retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01963/stems/S06.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01963/stems/S06.wav'
# Failed to load background instrument Synth Brass 1, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02079/stems/S11.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02079/stems/S11.wav'
# Failed to load background instrument FX 4 (atmosphere), retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01945/stems/S07.wav
# 95 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav')) {'Slap Bass 2', 'Tenor Sax', 'Synth Strings 2', 'Clavinet'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Slap Bass 2", "Tenor Sax", "Synth Strings 2", "Clavinet"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02062/stems/S02.wav
# 96 ('sax', 'sax', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02038/stems/S11.wav')) {'Tremolo Strings', 'Honky-tonk Piano', 'String Ensemble 2', 'Acoustic Guitar (nylon)'} {"prompt": "sax", "target_instrument": "sax", "background_instruments": ["Tremolo Strings", "Honky-tonk Piano", "String Ensemble 2", "Acoustic Guitar (nylon)"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01908/stems/S03.wav
# 97 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02017/stems/S01.wav')) {'Overdriven Guitar', 'Lead 6 (voice)', 'Tuba', 'Clavinet'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Overdriven Guitar", "Lead 6 (voice)", "Tuba", "Clavinet"]}
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S09.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02040/stems/S09.wav'
# Failed to load background instrument Steel Drums, retrying...
# audio.load_audio_segment : error loading /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S08.wav: [Errno 2] No such file or directory: '/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01918/stems/S08.wav'
# Failed to load background instrument Timpani, retrying...
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01967/stems/S07.wav
# 98 ('piano', 'piano', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01903/stems/S08.wav')) {'Rock Organ', 'String Ensemble 2', 'Violin', 'Xylophone'} {"prompt": "piano", "target_instrument": "piano", "background_instruments": ["Rock Organ", "String Ensemble 2", "Violin", "Xylophone"]}
# /media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track02000/stems/S09.wav
# 99 ('violin', 'violin', PosixPath('/media/eilen/EXTERNAL_USB/Research/Data/Datasets/slakh2100_yourmt3_16k/test/Track01998/stems/S05.wav')) {'Rock Organ', 'Distortion Guitar', 'Celesta', 'Pad 6 (metallic)'} {"prompt": "violin", "target_instrument": "violin", "background_instruments": ["Rock Organ", "Distortion Guitar", "Celesta", "Pad 6 (metallic)"]}

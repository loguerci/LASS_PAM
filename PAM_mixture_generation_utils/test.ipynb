# %%
import audio as aud
import parsing
import librosa as lr
from IPython.display import display, Audio
import os
import numpy as np
from pathlib import Path


audio_dir = "/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00001/stems"
audios = [aud.load_audio_segment(os.path.join(audio_dir, f)) for f in os.listdir(audio_dir) if f.endswith(".wav")]
res = aud.scatter_audio_segments(audios, mix_duration_s=30, mix_division=5, instance_probability=.5, max_seg_duration_s=5.0)

display(Audio(res, rate=16000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
res = parsing.track_metadata(Path("/home/eilen/Code/Python/LASS_PAM/data/raw/babyslakh_16k/Track00002"))
for s, v in res['stems'].items():
    print(s, v['midi_program_name'])

res = parsing.track_stems_and_instr(res)
print(res)
filt = ["string", "violin", "piano", "choir"]
reject = ["electric"]
print(parsing.filter_stems_by_keywords(res, filt, reject))
# Out:
# {'UUID': '0c3b7bf33cd3d67970ecfc06339bfc49', 'audio_dir': 'stems', 'lmd_midi_dir': 'lmd_matched/I/V/S/TRIVSGU128F14592BB/0c3b7bf33cd3d67970ecfc06339bfc49.mid', 'midi_dir': 'MIDI', 'normalization_factor': -13.0, 'normalized': True, 'overall_gain': 0.15620431779447091, 'stems': {'S00': {'audio_rendered': False, 'inst_class': 'Strings (continued)', 'integrated_loudness': -19.14115696924754, 'is_drum': False, 'midi_program_name': 'Synth Strings 1', 'midi_saved': False, 'plugin_name': 'session_strings_pro_2_ensemble_traditional.nkm', 'program_num': 50}, 'S01': {'audio_rendered': False, 'inst_class': 'Bass', 'integrated_loudness': -18.291045576390164, 'is_drum': False, 'midi_program_name': 'Electric Bass (pick)', 'midi_saved': False, 'plugin_name': 'classic_bass.nkm', 'program_num': 34}, 'S02': {'audio_rendered': False, 'inst_class': 'Synth Lead', 'integrated_loudness': -16.698807050925982, 'is_drum': False, 'midi_program_name': 'Lead 2 (sawtooth)', 'midi_saved': False, 'plugin_name': 'processor_lead.nkm', 'program_num': 81}, 'S03': {'audio_rendered': False, 'inst_class': 'Synth Pad', 'integrated_loudness': -22.340055580828253, 'is_drum': False, 'midi_program_name': 'Pad 1 (new age)', 'midi_saved': False, 'plugin_name': 'cold_cave.nkm', 'program_num': 88}, 'S04': {'audio_rendered': False, 'inst_class': 'Strings (continued)', 'integrated_loudness': -16.006649615187683, 'is_drum': False, 'midi_program_name': 'Choir Aahs', 'midi_saved': False, 'plugin_name': 'choir_e.nkm', 'program_num': 52}, 'S05': {'audio_rendered': False, 'inst_class': 'Chromatic Percussion', 'integrated_loudness': -13.99961085505928, 'is_drum': False, 'midi_program_name': 'Music Box', 'midi_saved': False, 'plugin_name': 'glockenspiel.nkm', 'program_num': 10}, 'S06': {'audio_rendered': False, 'inst_class': 'Piano', 'integrated_loudness': -19.9533198393771, 'is_drum': False, 'midi_program_name': 'Clavinet', 'midi_saved': False, 'plugin_name': 'scarbee_a_200.nkm', 'program_num': 7}, 'S07': {'audio_rendered': False, 'inst_class': 'Brass', 'integrated_loudness': -16.53078527982276, 'is_drum': False, 'midi_program_name': 'Brass Section', 'midi_saved': False, 'plugin_name': 'session_horns_pro_keyswitch_60s_horns.nkm', 'program_num': 61}, 'S08': {'audio_rendered': False, 'inst_class': 'Guitar', 'integrated_loudness': -27.275467047625614, 'is_drum': False, 'midi_program_name': 'Electric Guitar (muted)', 'midi_saved': False, 'plugin_name': 'jazz_guitar.nkm', 'program_num': 28}, 'S09': {'audio_rendered': False, 'inst_class': 'Drums', 'integrated_loudness': -25.20809688149238, 'is_drum': True, 'midi_program_name': 'Drums', 'midi_saved': False, 'plugin_name': 'garage_kit_lite.nkm', 'program_num': 128}, 'S10': {'audio_rendered': False, 'inst_class': 'Percussive', 'is_drum': False, 'midi_program_name': 'Woodblock', 'midi_saved': False, 'plugin_name': 'None', 'program_num': 115}, 'S11': {'audio_rendered': False, 'inst_class': 'Strings (continued)', 'is_drum': False, 'midi_program_name': 'Orchestra Hit', 'midi_saved': False, 'plugin_name': 'None', 'program_num': 55}}, 'target_peak': -1.0}
# S00 Synth Strings 1
# S01 Electric Bass (pick)
# S02 Lead 2 (sawtooth)
# S03 Pad 1 (new age)
# S04 Choir Aahs
# S05 Music Box
# S06 Clavinet
# S07 Brass Section
# S08 Electric Guitar (muted)
# S09 Drums
# S10 Woodblock
# S11 Orchestra Hit
# {'S00': 'Synth Strings 1', 'S01': 'Electric Bass (pick)', 'S02': 'Lead 2 (sawtooth)', 'S03': 'Pad 1 (new age)', 'S04': 'Choir Aahs', 'S05': 'Music Box', 'S06': 'Clavinet', 'S07': 'Brass Section', 'S08': 'Electric Guitar (muted)', 'S09': 'Drums', 'S10': 'Woodblock', 'S11': 'Orchestra Hit'}
# {'S00': 'Synth Strings 1', 'S04': 'Choir Aahs'}
